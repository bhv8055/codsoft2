# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import shap
import optuna
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler,StandardScaler
plt.style.use("ggplot")
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/kaggle/input/imdb-india-movies/IMDb Movies India.csv',encoding='ISO-8859-1').drop(columns='Name')
df.dropna(inplace = True)

# %%
df.head()
# Out:
#      Year Duration                      Genre  Rating  Votes        Director  \
# 1  (2019)  109 min                      Drama     7.0      8   Gaurav Bakshi
# 3  (2019)  110 min            Comedy, Romance     4.4     35      Ovais Khan
# 5  (1997)  147 min     Comedy, Drama, Musical     4.7    827    Rahul Rawail
# 6  (2005)  142 min        Drama, Romance, War     7.4  1,086  Shoojit Sircar
# 8  (2012)   82 min  Horror, Mystery, Thriller     5.6    326   Allyson Patel
#
#            Actor 1                 Actor 2          Actor 3
# 1     Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 3          Prateik              Ishita Raj  Siddhant Kapoor
# 5       Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6  Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 8        Yash Dave          Muntazir Ahmad     Kiran Bhatia

# %%
df.shape
# Out:
# (5659, 9)

# %%
df.isna().sum()
# Out:
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5659 entries, 1 to 15508
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      5659 non-null   object
#  1   Duration  5659 non-null   object
#  2   Genre     5659 non-null   object
#  3   Rating    5659 non-null   float64
#  4   Votes     5659 non-null   object
#  5   Director  5659 non-null   object
#  6   Actor 1   5659 non-null   object
#  7   Actor 2   5659 non-null   object
#  8   Actor 3   5659 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 442.1+ KB

# %%
df.nunique()
# Out:
# Year          91
# Duration     174
# Genre        376
# Rating        83
# Votes       2027
# Director    2431
# Actor 1     1960
# Actor 2     2321
# Actor 3     2556
# dtype: int64

# %%
# Function to plot pie chart
def plot_pie_chart(column):
    plt.figure(figsize=(8, 8))
    df[column].value_counts().head(10).plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'), wedgeprops=dict(width=0.3))
    plt.title(f'Distribution of {column}')
    plt.ylabel('')
    plt.show()
    
    
def plot_hist_chart(column):
    plt.figure(figsize=(10, 5))
    df[column].hist()
    plt.title(f'{column} Distribution')
    plt.xlabel('Index')
    plt.ylabel(column)
    plt.show()

# Plotting for each column
for col in df.columns:
    if df[col].dtype == 'object':
        plot_pie_chart(col)
    else:
        plot_hist_chart(col)

# %%
# Remove () and convert dtype if year to int 
df['Year'] = df['Year'].str.replace('(','')
df['Year'] = df['Year'].str.replace(')','').astype(int)

df['Duration'] = df['Duration'].str.split(' ',expand=True)[0].astype(float)

df['Votes'] = df['Votes'].str.replace(',','').astype(int)

df
# Out:
#        Year  Duration                      Genre  Rating  Votes  \
# 1      2019     109.0                      Drama     7.0      8
# 3      2019     110.0            Comedy, Romance     4.4     35
# 5      1997     147.0     Comedy, Drama, Musical     4.7    827
# 6      2005     142.0        Drama, Romance, War     7.4   1086
# 8      2012      82.0  Horror, Mystery, Thriller     5.6    326
# ...     ...       ...                        ...     ...    ...
# 15493  2015     115.0                      Drama     6.1    408
# 15494  2001     153.0  Biography, Drama, History     6.2   1496
# 15503  1989     125.0       Action, Crime, Drama     5.8     44
# 15505  1999     129.0              Action, Drama     4.5    655
# 15508  1998     130.0              Action, Drama     6.2     20
#
#               Director          Actor 1                 Actor 2  \
# 1        Gaurav Bakshi     Rasika Dugal          Vivek Ghamande
# 3           Ovais Khan          Prateik              Ishita Raj
# 5         Rahul Rawail       Bobby Deol  Aishwarya Rai Bachchan
# 6       Shoojit Sircar  Jimmy Sheirgill          Minissha Lamba
# 8        Allyson Patel        Yash Dave          Muntazir Ahmad
# ...                ...              ...                     ...
# 15493      Mozez Singh    Vicky Kaushal         Sarah Jane Dias
# 15494    Shyam Benegal   Karisma Kapoor                   Rekha
# 15503  S.P. Muthuraman      Chiranjeevi              Jayamalini
# 15505       Kuku Kohli     Akshay Kumar          Twinkle Khanna
# 15508     K.C. Bokadia       Dharmendra              Jaya Prada
#
#                 Actor 3
# 1         Arvind Jangid
# 3       Siddhant Kapoor
# 5         Shammi Kapoor
# 6        Yashpal Sharma
# 8          Kiran Bhatia
# ...                 ...
# 15493  Raaghavv Chanana
# 15494    Manoj Bajpayee
# 15503       Rajinikanth
# 15505       Aruna Irani
# 15508       Arjun Sarja
#
# [5659 rows x 9 columns]

# %%
dar ={}
for index, row in df.iterrows():
    director = row['Director']
    rating = row['Rating']
    if director in dar:
        dar[director]['sum']+=rating
        dar[director]['count']+= 1
    else:
            dar[director] = {'sum':rating,'count':1}
df['Director Average Rating'] = df['Director'].apply(lambda x: dar[x]['sum']/dar[x]['count'])

# %%
aar ={}
for index, row in df.iterrows():
    actors =row['Actor 1'].split(', ')
    rating = row['Rating']
    for actor in actors:
        if actor in aar:
            aar[actor]['sum']+=rating
            aar[actor]['count']+= 1
        else:
             aar[actor] = {'sum': rating,'count':1}
def claa(row):
    actors = row['Actor 1'].split(', ')
    lar = [aar[actor]['sum']/aar[actor]['count'] for actor in actors]
    return max(lar)
df['Lead Actor Average Rating'] = df.apply(claa,axis=1)

# %%
df['Genre1'] = df.Genre.str.split(',',expand = True)[0]
df['Genre2'] = df.Genre.str.split(',',expand = True)[1]
df['Genre3'] = df.Genre.str.split(',',expand = True)[2]

# %%
df = df.drop(columns = ['Genre','Director','Actor 1','Actor 2','Actor 3'])

# %%
df.shape[0]
# Out:
# 5659

# %%
df.shape
# Out:
# (5659, 9)

# %%
df.isna().sum()
# Out:
# Year                            0
# Duration                        0
# Rating                          0
# Votes                           0
# Director Average Rating         0
# Lead Actor Average Rating       0
# Genre1                          0
# Genre2                       1658
# Genre3                       3340
# dtype: int64

# %%
df.fillna(0)
for i in df.index:
    if df.at[i,'Genre2'] == 0:
        df.at[i,'Genre2'] = df.at[i,'Genre1']
    elif df.at[i,'Genre3'] == 0:
        df.at[i,'Genre3'] = df.at[i,'Genre2']

# %%
df.isna().sum()
# Out:
# Year                            0
# Duration                        0
# Rating                          0
# Votes                           0
# Director Average Rating         0
# Lead Actor Average Rating       0
# Genre1                          0
# Genre2                       1658
# Genre3                       3340
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5659 entries, 1 to 15508
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       5659 non-null   int64
#  1   Duration                   5659 non-null   float64
#  2   Rating                     5659 non-null   float64
#  3   Votes                      5659 non-null   int64
#  4   Director Average Rating    5659 non-null   float64
#  5   Lead Actor Average Rating  5659 non-null   float64
#  6   Genre1                     5659 non-null   object
#  7   Genre2                     4001 non-null   object
#  8   Genre3                     2319 non-null   object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 571.1+ KB

# %%
for col in ['Genre1','Genre2','Genre3']:
    df[col],_ = pd.factorize(df[col])
df.head()
# Out:
#    Year  Duration  Rating  Votes  Director Average Rating  \
# 1  2019     109.0     7.0      8                 7.000000
# 3  2019     110.0     4.4     35                 4.400000
# 5  1997     147.0     4.7    827                 5.313333
# 6  2005     142.0     7.4   1086                 7.383333
# 8  2012      82.0     5.6    326                 5.600000
#
#    Lead Actor Average Rating  Genre1  Genre2  Genre3
# 1                   6.850000       0      -1      -1
# 3                   5.420000       1       0      -1
# 5                   4.788889       1       1       0
# 6                   5.435000       0       0       1
# 8                   5.600000       2       2       2

# %%
target = 'Rating'
X = df.drop(columns=[target,'Duration'])
y = df[target]

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
# Define objective function for Optuna
def objective(trial):
    # Define hyperparameters to search
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 300, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 10),
        'verbosity': 0,
    }

    xgb = XGBRegressor(**param)

    # Fit the model on training data
    xgb.fit(X_train, y_train)

    # Predict on the validation set
    y_pred = xgb.predict(X_test)

    r2 = r2_score(y_test, y_pred)

    return r2

# Perform hyperparameter optimization using Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Print the best trial and parameters found
print("Best trial:")
best_trial = study.best_trial
print(f"  Value: {best_trial.value}")
print("  Params: ")
for key, value in best_trial.params.items():
    print(f"    {key}: {value}")
    
# Use the best parameters to train the final model
best_params = best_trial.params
# Out:
# [I 2024-09-11 17:14:38,622] A new study created in memory with name: no-name-e9f7cc4d-3700-40a7-b2cc-3c945eb70343
# [I 2024-09-11 17:14:39,183] Trial 0 finished with value: 0.7436457617509316 and parameters: {'n_estimators': 702, 'max_depth': 5, 'learning_rate': 0.0616300006455757, 'subsample': 0.7187143183542243, 'colsample_bytree': 0.6052052203591575, 'reg_alpha': 4.964739148313652, 'reg_lambda': 5.129997530726909}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:39,553] Trial 1 finished with value: 0.7383653101232375 and parameters: {'n_estimators': 319, 'max_depth': 7, 'learning_rate': 0.024809726705762, 'subsample': 0.980204067024524, 'colsample_bytree': 0.881139906894953, 'reg_alpha': 8.703105617389898, 'reg_lambda': 4.02010412442448}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:40,204] Trial 2 finished with value: 0.7361342000455855 and parameters: {'n_estimators': 563, 'max_depth': 7, 'learning_rate': 0.05340370941506334, 'subsample': 0.9623107914950039, 'colsample_bytree': 0.6686698477754855, 'reg_alpha': 2.4502733427168524, 'reg_lambda': 1.1784654419715457}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:40,656] Trial 3 finished with value: 0.7435253667241946 and parameters: {'n_estimators': 574, 'max_depth': 5, 'learning_rate': 0.02314200518510467, 'subsample': 0.7086716033147378, 'colsample_bytree': 0.8914434480128437, 'reg_alpha': 6.5197600384192995, 'reg_lambda': 9.012210835305813}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:40,915] Trial 4 finished with value: 0.7412339042757383 and parameters: {'n_estimators': 414, 'max_depth': 4, 'learning_rate': 0.06319996616216882, 'subsample': 0.818084017919909, 'colsample_bytree': 0.8972387155757016, 'reg_alpha': 8.9073715223154, 'reg_lambda': 4.890538796069123}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:41,779] Trial 5 finished with value: 0.7277888429588864 and parameters: {'n_estimators': 951, 'max_depth': 6, 'learning_rate': 0.09777533529128285, 'subsample': 0.8388942517908785, 'colsample_bytree': 0.6706835662276559, 'reg_alpha': 3.5702973346986813, 'reg_lambda': 8.049155366960415}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:42,321] Trial 6 finished with value: 0.7345936195918723 and parameters: {'n_estimators': 914, 'max_depth': 4, 'learning_rate': 0.07640225592552224, 'subsample': 0.6846925417784554, 'colsample_bytree': 0.6312377899479903, 'reg_alpha': 0.7495940069801721, 'reg_lambda': 7.373027337734188}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:43,270] Trial 7 finished with value: 0.7367501563645587 and parameters: {'n_estimators': 618, 'max_depth': 9, 'learning_rate': 0.053085561030352335, 'subsample': 0.749543683339292, 'colsample_bytree': 0.979640503175087, 'reg_alpha': 5.959745860024514, 'reg_lambda': 0.5160065974678485}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:43,565] Trial 8 finished with value: 0.7416388303771968 and parameters: {'n_estimators': 492, 'max_depth': 4, 'learning_rate': 0.08337241021074526, 'subsample': 0.8819865272090943, 'colsample_bytree': 0.709377017598626, 'reg_alpha': 5.147081965103278, 'reg_lambda': 3.501233782988611}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:44,251] Trial 9 finished with value: 0.7366187102723791 and parameters: {'n_estimators': 972, 'max_depth': 4, 'learning_rate': 0.08276715520094276, 'subsample': 0.9100654476219231, 'colsample_bytree': 0.8712572401020315, 'reg_alpha': 2.448131789394956, 'reg_lambda': 5.652178915868396}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:45,388] Trial 10 finished with value: 0.7433447612410264 and parameters: {'n_estimators': 790, 'max_depth': 10, 'learning_rate': 0.03915643425860185, 'subsample': 0.603104501294196, 'colsample_bytree': 0.7456937644155055, 'reg_alpha': 7.450395389495653, 'reg_lambda': 2.8703497003840304}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:46,097] Trial 11 finished with value: 0.7428714534944342 and parameters: {'n_estimators': 736, 'max_depth': 6, 'learning_rate': 0.015056711199399504, 'subsample': 0.7263603508088395, 'colsample_bytree': 0.7652389663802004, 'reg_alpha': 6.7230353256061175, 'reg_lambda': 9.914266949223858}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:46,692] Trial 12 finished with value: 0.7429862037628672 and parameters: {'n_estimators': 715, 'max_depth': 5, 'learning_rate': 0.03613266140734144, 'subsample': 0.6477331072440243, 'colsample_bytree': 0.8166043523779971, 'reg_alpha': 4.108715277204885, 'reg_lambda': 9.500984442027342}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:47,111] Trial 13 finished with value: 0.725704716040564 and parameters: {'n_estimators': 830, 'max_depth': 3, 'learning_rate': 0.010853358155413405, 'subsample': 0.7626731886657611, 'colsample_bytree': 0.9994558471442274, 'reg_alpha': 7.647168142992949, 'reg_lambda': 6.571299252406783}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:47,949] Trial 14 finished with value: 0.7419991655461872 and parameters: {'n_estimators': 553, 'max_depth': 8, 'learning_rate': 0.03926802898931524, 'subsample': 0.6930302263916036, 'colsample_bytree': 0.9399494647722219, 'reg_alpha': 5.351853333598283, 'reg_lambda': 8.310272107648712}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:48,515] Trial 15 finished with value: 0.7386064402949097 and parameters: {'n_estimators': 663, 'max_depth': 5, 'learning_rate': 0.0653667176872149, 'subsample': 0.7856220413128894, 'colsample_bytree': 0.8229974253240983, 'reg_alpha': 3.9933117570486565, 'reg_lambda': 2.1682086582749527}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:48,941] Trial 16 finished with value: 0.743420936803264 and parameters: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.02729787881676559, 'subsample': 0.6391328892293177, 'colsample_bytree': 0.842333551587285, 'reg_alpha': 6.316308583285731, 'reg_lambda': 5.975154990430035}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:49,269] Trial 17 finished with value: 0.7393001756145402 and parameters: {'n_estimators': 641, 'max_depth': 3, 'learning_rate': 0.04736424814529197, 'subsample': 0.7076066186272167, 'colsample_bytree': 0.6137133577635435, 'reg_alpha': 9.999888545361104, 'reg_lambda': 4.703361881567225}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:50,223] Trial 18 finished with value: 0.7279280680684738 and parameters: {'n_estimators': 841, 'max_depth': 6, 'learning_rate': 0.0652613037138903, 'subsample': 0.6641998194917709, 'colsample_bytree': 0.941531810089108, 'reg_alpha': 0.7305418314519896, 'reg_lambda': 8.61773951904011}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:50,864] Trial 19 finished with value: 0.7416408897432185 and parameters: {'n_estimators': 419, 'max_depth': 8, 'learning_rate': 0.02676634775143502, 'subsample': 0.6035026700922641, 'colsample_bytree': 0.7772864284837266, 'reg_alpha': 2.637980964777955, 'reg_lambda': 7.152761804617033}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:51,448] Trial 20 finished with value: 0.7394057971155383 and parameters: {'n_estimators': 725, 'max_depth': 5, 'learning_rate': 0.07352405266158363, 'subsample': 0.7868555352823028, 'colsample_bytree': 0.7245219917109188, 'reg_alpha': 7.516677191042173, 'reg_lambda': 2.3007098929926277}. Best is trial 0 with value: 0.7436457617509316.
# [I 2024-09-11 17:14:51,879] Trial 21 finished with value: 0.7438030027669804 and parameters: {'n_estimators': 509, 'max_depth': 5, 'learning_rate': 0.030030235363128065, 'subsample': 0.6418756721084959, 'colsample_bytree': 0.8414196618024439, 'reg_alpha': 6.407312664782191, 'reg_lambda': 6.044171551513058}. Best is trial 21 with value: 0.7438030027669804.
# [I 2024-09-11 17:14:52,374] Trial 22 finished with value: 0.7423959126855966 and parameters: {'n_estimators': 579, 'max_depth': 5, 'learning_rate': 0.017994760860252607, 'subsample': 0.7328664799975207, 'colsample_bytree': 0.9189495255822036, 'reg_alpha': 4.984126839212372, 'reg_lambda': 5.66335934861508}. Best is trial 21 with value: 0.7438030027669804.
# [I 2024-09-11 17:14:52,872] Trial 23 finished with value: 0.743755461577574 and parameters: {'n_estimators': 476, 'max_depth': 6, 'learning_rate': 0.03310342000956728, 'subsample': 0.6429427097479659, 'colsample_bytree': 0.8474191613174599, 'reg_alpha': 5.896643544035661, 'reg_lambda': 4.170836696086708}. Best is trial 21 with value: 0.7438030027669804.
# [I 2024-09-11 17:14:53,402] Trial 24 finished with value: 0.7423327614214728 and parameters: {'n_estimators': 415, 'max_depth': 7, 'learning_rate': 0.0457151632779039, 'subsample': 0.6387210405847408, 'colsample_bytree': 0.8011462363672063, 'reg_alpha': 4.804191367702807, 'reg_lambda': 4.169182487638549}. Best is trial 21 with value: 0.7438030027669804.
# [I 2024-09-11 17:14:54,051] Trial 25 finished with value: 0.743422268751246 and parameters: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.03441696183717505, 'subsample': 0.6679680854174906, 'colsample_bytree': 0.8634430060355752, 'reg_alpha': 5.634942363852858, 'reg_lambda': 6.568635788556874}. Best is trial 21 with value: 0.7438030027669804.
# [I 2024-09-11 17:14:54,475] Trial 26 finished with value: 0.7417085188498128 and parameters: {'n_estimators': 301, 'max_depth': 8, 'learning_rate': 0.046487534879655026, 'subsample': 0.6255309714573919, 'colsample_bytree': 0.8447613330929731, 'reg_alpha': 6.956025101868269, 'reg_lambda': 3.2026374848335486}. Best is trial 21 with value: 0.7438030027669804.
# [I 2024-09-11 17:14:54,867] Trial 27 finished with value: 0.7438070167073916 and parameters: {'n_estimators': 354, 'max_depth': 6, 'learning_rate': 0.06067977609054742, 'subsample': 0.6823874345738372, 'colsample_bytree': 0.7839678790882992, 'reg_alpha': 8.43367792950027, 'reg_lambda': 5.183543062492305}. Best is trial 27 with value: 0.7438070167073916.
# [I 2024-09-11 17:14:55,294] Trial 28 finished with value: 0.7442311427189288 and parameters: {'n_estimators': 357, 'max_depth': 7, 'learning_rate': 0.05718026225435904, 'subsample': 0.6759818206761791, 'colsample_bytree': 0.780496837149873, 'reg_alpha': 8.2276594171421, 'reg_lambda': 4.1844464189277755}. Best is trial 28 with value: 0.7442311427189288.
# [I 2024-09-11 17:14:55,734] Trial 29 finished with value: 0.7446868950032052 and parameters: {'n_estimators': 371, 'max_depth': 7, 'learning_rate': 0.059875045857380765, 'subsample': 0.6737781377638733, 'colsample_bytree': 0.7786659200216468, 'reg_alpha': 8.471332007003474, 'reg_lambda': 5.2456346326034655}. Best is trial 29 with value: 0.7446868950032052.
# [I 2024-09-11 17:14:56,264] Trial 30 finished with value: 0.7418300566719899 and parameters: {'n_estimators': 362, 'max_depth': 9, 'learning_rate': 0.05763856816600026, 'subsample': 0.7591519447620323, 'colsample_bytree': 0.7829739359137214, 'reg_alpha': 8.656759690547318, 'reg_lambda': 5.1113992371387305}. Best is trial 29 with value: 0.7446868950032052.
# [I 2024-09-11 17:14:56,694] Trial 31 finished with value: 0.7422723230253704 and parameters: {'n_estimators': 362, 'max_depth': 7, 'learning_rate': 0.07036432065002629, 'subsample': 0.6784581312351902, 'colsample_bytree': 0.745887695883087, 'reg_alpha': 8.176315708865003, 'reg_lambda': 6.059262350251397}. Best is trial 29 with value: 0.7446868950032052.
# [I 2024-09-11 17:14:57,108] Trial 32 finished with value: 0.7450743553536532 and parameters: {'n_estimators': 364, 'max_depth': 7, 'learning_rate': 0.05812047047287692, 'subsample': 0.6658306212098065, 'colsample_bytree': 0.8006746948490142, 'reg_alpha': 9.672836154056759, 'reg_lambda': 4.261980292210226}. Best is trial 32 with value: 0.7450743553536532.
# [I 2024-09-11 17:14:57,505] Trial 33 finished with value: 0.7422012172656787 and parameters: {'n_estimators': 354, 'max_depth': 7, 'learning_rate': 0.05824891414310311, 'subsample': 0.6966091541283939, 'colsample_bytree': 0.7034233130360993, 'reg_alpha': 9.800349416627624, 'reg_lambda': 3.685739971776309}. Best is trial 32 with value: 0.7450743553536532.
# [I 2024-09-11 17:14:58,059] Trial 34 finished with value: 0.7429916165228831 and parameters: {'n_estimators': 443, 'max_depth': 8, 'learning_rate': 0.05234060080127173, 'subsample': 0.7294435012038748, 'colsample_bytree': 0.7998429224114585, 'reg_alpha': 9.243671380785726, 'reg_lambda': 4.557108359819084}. Best is trial 32 with value: 0.7450743553536532.
# [I 2024-09-11 17:14:58,451] Trial 35 finished with value: 0.7459003074363648 and parameters: {'n_estimators': 329, 'max_depth': 7, 'learning_rate': 0.06864659425134247, 'subsample': 0.6667203879633835, 'colsample_bytree': 0.7508743282578473, 'reg_alpha': 8.258021715385128, 'reg_lambda': 2.225582901261986}. Best is trial 35 with value: 0.7459003074363648.
# [I 2024-09-11 17:14:58,827] Trial 36 finished with value: 0.7463560782521261 and parameters: {'n_estimators': 323, 'max_depth': 7, 'learning_rate': 0.08065488312130284, 'subsample': 0.662500819643347, 'colsample_bytree': 0.736003835394148, 'reg_alpha': 9.293593735311434, 'reg_lambda': 1.9955469203345837}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:14:59,197] Trial 37 finished with value: 0.7420261006593867 and parameters: {'n_estimators': 303, 'max_depth': 9, 'learning_rate': 0.09298030919575681, 'subsample': 0.6201060369094061, 'colsample_bytree': 0.6712084153470589, 'reg_alpha': 9.450179963557714, 'reg_lambda': 1.440192044641414}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:14:59,679] Trial 38 finished with value: 0.7443936229751744 and parameters: {'n_estimators': 387, 'max_depth': 8, 'learning_rate': 0.08868465714304641, 'subsample': 0.658586924593893, 'colsample_bytree': 0.7448546770497197, 'reg_alpha': 9.136136067674974, 'reg_lambda': 1.268873819996343}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:00,138] Trial 39 finished with value: 0.7430471820437954 and parameters: {'n_estimators': 446, 'max_depth': 7, 'learning_rate': 0.06829793357609583, 'subsample': 0.8232544417339407, 'colsample_bytree': 0.6978051830944315, 'reg_alpha': 9.49193638273283, 'reg_lambda': 0.5008996452963455}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:00,540] Trial 40 finished with value: 0.7418071183990909 and parameters: {'n_estimators': 329, 'max_depth': 8, 'learning_rate': 0.07767635593806141, 'subsample': 0.711126238131773, 'colsample_bytree': 0.6474304395652457, 'reg_alpha': 8.843806330795292, 'reg_lambda': 1.9631088284004394}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:01,029] Trial 41 finished with value: 0.7445200980254768 and parameters: {'n_estimators': 391, 'max_depth': 8, 'learning_rate': 0.08929675848449371, 'subsample': 0.6616099647185465, 'colsample_bytree': 0.7463296399217791, 'reg_alpha': 9.113094224395876, 'reg_lambda': 1.264969238717615}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:01,428] Trial 42 finished with value: 0.7429613726643698 and parameters: {'n_estimators': 330, 'max_depth': 7, 'learning_rate': 0.08222744691370353, 'subsample': 0.6210177271636519, 'colsample_bytree': 0.7325584484373959, 'reg_alpha': 7.884894282800042, 'reg_lambda': 2.6610393198973545}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:01,991] Trial 43 finished with value: 0.7390712670858106 and parameters: {'n_estimators': 393, 'max_depth': 9, 'learning_rate': 0.09107820969965082, 'subsample': 0.6573114395977867, 'colsample_bytree': 0.7586020896794033, 'reg_alpha': 7.1603970577825375, 'reg_lambda': 0.09857032900181828}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:02,456] Trial 44 finished with value: 0.7428436529288956 and parameters: {'n_estimators': 393, 'max_depth': 7, 'learning_rate': 0.07863686471734543, 'subsample': 0.95644487691812, 'colsample_bytree': 0.7196847710160543, 'reg_alpha': 8.701839319355804, 'reg_lambda': 1.7229990315772594}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:02,949] Trial 45 finished with value: 0.7411088104549115 and parameters: {'n_estimators': 454, 'max_depth': 8, 'learning_rate': 0.09841260604969032, 'subsample': 0.6988514342456702, 'colsample_bytree': 0.6853578748644251, 'reg_alpha': 9.799807720867149, 'reg_lambda': 0.747837346534225}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:03,308] Trial 46 finished with value: 0.741809148975541 and parameters: {'n_estimators': 332, 'max_depth': 6, 'learning_rate': 0.0736555993438616, 'subsample': 0.7428607264516215, 'colsample_bytree': 0.8042925881270802, 'reg_alpha': 7.865297428509936, 'reg_lambda': 2.8144553569698623}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:03,978] Trial 47 finished with value: 0.7408535848953011 and parameters: {'n_estimators': 389, 'max_depth': 10, 'learning_rate': 0.08682824029875588, 'subsample': 0.8712863764888245, 'colsample_bytree': 0.7635371009728424, 'reg_alpha': 8.80786345527602, 'reg_lambda': 3.370157628888659}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:04,515] Trial 48 finished with value: 0.7436665253877514 and parameters: {'n_estimators': 430, 'max_depth': 8, 'learning_rate': 0.07018902758137176, 'subsample': 0.7139340527023297, 'colsample_bytree': 0.7354950376601921, 'reg_alpha': 9.552911233381485, 'reg_lambda': 1.6501999761071051}. Best is trial 36 with value: 0.7463560782521261.
# [I 2024-09-11 17:15:05,106] Trial 49 finished with value: 0.7436455638393793 and parameters: {'n_estimators': 553, 'max_depth': 7, 'learning_rate': 0.08000273074103396, 'subsample': 0.609213998279109, 'colsample_bytree': 0.8256747465647802, 'reg_alpha': 9.115860608151445, 'reg_lambda': 1.002186788850865}. Best is trial 36 with value: 0.7463560782521261.
# Best trial:
#   Value: 0.7463560782521261
#   Params:
#     n_estimators: 323
#     max_depth: 7
#     learning_rate: 0.08065488312130284
#     subsample: 0.662500819643347
#     colsample_bytree: 0.736003835394148
#     reg_alpha: 9.293593735311434
#     reg_lambda: 1.9955469203345837

# %%
xgb_normal = XGBRegressor(**best_params)


xgb_normal.fit(X_train, y_train,eval_set=[(X_train, y_train), (X_test,y_test)],verbose=0)

# Make predictions on the test set
y_pred_test = xgb_normal.predict(X_test)

mae = mean_absolute_error(y_test,y_pred_test)


print("Test MAE:",mae )
# Out:
# Test MAE: 0.48800598273428925

# %%
results = xgb_normal.evals_result()
val_rmse = results["validation_1"]['rmse']
best_epopch = min(val_rmse)
i_best_epoch = val_rmse.index(best_epopch)
epochs = len(results['validation_0']['rmse'])
x_axis = range(0, epochs)
    
# plot m log loss
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['rmse'], label='Train')
ax.plot(x_axis, results['validation_1']['rmse'], label='Test')
ax.plot(i_best_epoch, best_epopch, marker="o", color="green", label="Best")
ax.legend()
plt.ylabel('rmse')
plt.title('XGBoost rmse')
plt.show()

# %%
plt.scatter(y_test, y_pred_test, alpha=0.7, label='Real')
plt.plot([y_test.min(), y_test.max()],[y_test.min(), y_test.max()], '--', c='.3')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot XGBoost Model')
plt.show()

# %%
residuals = y_test - y_pred_test
plt.scatter(y_test, residuals, label='Residuals', alpha=0.7)
plt.axhline(y=0, color='red', linestyle='--', label='Zero Residuals')
plt.xlabel('Actual Values')
plt.ylabel('Residuals')
plt.title('Residual Plot for XGBoost')
plt.legend()
plt.show()

# %%
# Optianing the most features that had an impact of our price
def plot_feature_importance(model, feature_names=None, plot=True):

    feature_importance = model.feature_importances_
    
    if feature_names is None:
        feature_names = model.feature_name()

    feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

    if plot:
        plt.figure(figsize=(10, 10))
        sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
        plt.title('Feature Importance')
        plt.show()

    return feature_importance_df

feature_importance_df = plot_feature_importance(xgb_normal,feature_names=df.drop(columns=[target,'Duration']).columns)
